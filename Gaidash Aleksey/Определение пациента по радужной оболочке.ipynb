# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/IrisID_gr2/blob/Gaidash-Alexey-folder/Gaidash%20Aleksey/%D0%9E%D0%BF%D1%80%D0%B5%D0%B4%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BF%D0%B0%D1%86%D0%B8%D0%B5%D0%BD%D1%82%D0%B0%20%D0%BF%D0%BE%20%D1%80%D0%B0%D0%B4%D1%83%D0%B6%D0%BD%D0%BE%D0%B9%20%D0%BE%D0%B1%D0%BE%D0%BB%D0%BE%D1%87%D0%BA%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Подключение класса для создания нейронной сети прямого распространения
from tensorflow.keras.models import Sequential 
# Подключение класса для создания полносвязного слоя
from tensorflow.keras.layers import Dense 
# Подключение оптимизатора
from tensorflow.keras.optimizers import Adam 
# Подключение утилит для to_categorical
from tensorflow.keras import utils 
# Подключение библиотеки для загрузки изображений
from tensorflow.keras.preprocessing import image 
# Подключение библиотеки для работы с массивами
import numpy as np 
# Подключение библиотек для отрисовки изображений
import matplotlib.pyplot as plt 
# Подключение модуля для работы с файлами
import os

from PIL import Image;
# для распаковки архивов
import zipfile;
import shutil;
# для рзавёртывания изображения на плоскости
import cv2;
# Вывод изображения в ноутбуке, а не в консоли или файле
# %matplotlib inline

# %%
# Загрузка датасета из облака
import gdown
gdown.download('https://drive.google.com/uc?id=1ZAXRuE6ly8nJG-eGFTkD9Pn663ihCedB', None, quiet=True)
# Out:
# 'Iris_ID.zip'

# %%
# Распаковываем архив Iris_ID.zip в папку Iris_ID
# !unzip -q Iris_ID.zip

# %%
# Распакуем вложенные архивы
# Путь к директории с базой
base_dir = '/content/Iris_ID';
dataset_dir = 'dataset';
labels = [];
train_dir = '/content/train'

for path in os.listdir(base_dir):
  with zipfile.ZipFile(base_dir + '/' + path, 'r') as zip_ref:
    name_zip = dataset_dir + '/' + path.split('.')[0];
    zip_ref.extractall(name_zip);
    
    for n in os.listdir(name_zip):
      d_name = train_dir + '/' + n[:-6];
      if os.path.exists(d_name) == False:
        os.makedirs(d_name);

      labels.append(n[:-6]);
      shutil.move(name_zip + '/' + n, d_name);

# %%
datasetPath = '/content/train';

x_train = [];
y_train = [];
NUM_CLASSES = 0;
IMG_WIDTH = 100;
IMG_HEIGHT = 100;
Dirs = os.listdir(datasetPath);

# Перебираем каждую директорию
for dir in Dirs:
  # Преобразовываем каждую картинку в массив байт
  for img in os.listdir(datasetPath + '/' + dir):
    i = Image.open(datasetPath + '/' + dir + '/' + img);
    i = i.resize((IMG_WIDTH, IMG_HEIGHT));
    #for t in range(60):
    np_arr = np.array(i); 
    x_train.append(np_arr);
    y_train.append(NUM_CLASSES);

  NUM_CLASSES = NUM_CLASSES + 1;

# Преобразование в numpy-массив загруженных изображений и меток классов, а также
# категоризацция меток

# Нормированние массива изображений
x_train = np.array(x_train);

# отберём 10% на валидационную выборку
index = int(len(x_train) / 10);
x_val = x_train[-index:];

x_val = np.array(x_val);

y_val = y_train[-index:];

y_train = utils.to_categorical(y_train, NUM_CLASSES)
y_train = np.array(y_train);

y_val = utils.to_categorical(y_val, NUM_CLASSES);
y_val = np.array(y_val);

# Вывод размерностей
print('Размер массива x_train', x_train.shape);
print('Размер массива y_train', y_train.shape);
print('Размер массива x_val', x_val.shape);
print('Размер массива y_val', y_val.shape);
# Out:
# Размер массива x_train (384, 100, 100, 3)
# Размер массива y_train (384, 128)
# Размер массива x_val (38, 100, 100, 3)
# Размер массива y_val (38, 128)

# %%
# Примеры картинок с метками
fig = plt.figure(figsize=(10,10))

for i in range(10): 
    n = np.random.randint(0 , x_train.shape[0])
    img = x_train[n];
    ax = fig.add_subplot(5, 5, i+1);
    label = Dirs[np.argmax(y_train[n])];
    ax.set_title(label)
    ax.imshow(img)
    ax.axis('off')
plt.show();

print();
print("Выведем несколько картоник с метками из валидацианной выборки");
print();

fig = plt.figure(figsize=(10,10))

for i in range(5):
  n = np.random.randint(0 , x_val.shape[0])
  imageData = x_val[n];
  ax = fig.add_subplot(5, 5, i+1);
  label = Dirs[np.argmax(y_val[n])];
  ax.set_title(label)
  ax.imshow(imageData)
  ax.axis('off')
plt.show();
# Out:
# Выведем несколько картоник с метками из валидацианной выборки

# %% [markdown]
# Создадим свёрточную нейронную сеть

# %%
from tensorflow.keras.models import Sequential;

from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization;

model = Sequential();
model.add(Conv2D(512, (3, 3), padding='same', activation='relu', input_shape=(100, 100, 3)));
model.add(BatchNormalization());
model.add(Conv2D(256, (3, 3), strides = (3,3), padding='same', activation='relu'));
model.add(MaxPooling2D(pool_size=(3, 3)));
model.add(BatchNormalization());
model.add(Conv2D(128, (3, 3), strides = (3,3), padding='valid', activation='relu'));
model.add(MaxPooling2D(pool_size=(3, 3)));
model.add(Flatten());
model.add(Dense(NUM_CLASSES, activation='softmax'));
print(model.summary());
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 512)     14336
#
#  batch_normalization (BatchN  (None, 100, 100, 512)    2048
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 34, 34, 256)       1179904
#
#  max_pooling2d (MaxPooling2D  (None, 11, 11, 256)      0
#  )
#
#  batch_normalization_1 (Batc  (None, 11, 11, 256)      1024
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         295040
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
# =================================================================
# Total params: 1,508,864
# Trainable params: 1,507,328
# Non-trainable params: 1,536
# _________________________________________________________________
# None

# %%
# Подключение оптимизатора Adam
from tensorflow.keras.optimizers import Adam

# Компиляция модели
model.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), batch_size=50, epochs=30, verbose=1)
# Out:
# Epoch 1/30
# 8/8 [==============================] - 125s 15s/step - loss: 6.0741 - accuracy: 0.0104 - val_loss: 66.4856 - val_accuracy: 0.0789
# Epoch 2/30
# 8/8 [==============================] - 125s 16s/step - loss: 4.7443 - accuracy: 0.0417 - val_loss: 52.5551 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 8/8 [==============================] - 130s 16s/step - loss: 4.2777 - accuracy: 0.0755 - val_loss: 44.5242 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 8/8 [==============================] - 125s 16s/step - loss: 3.7283 - accuracy: 0.1432 - val_loss: 28.7482 - val_accuracy: 0.1316
# Epoch 5/30
# 8/8 [==============================] - 124s 16s/step - loss: 3.2241 - accuracy: 0.2396 - val_loss: 28.7593 - val_accuracy: 0.1053
# Epoch 6/30
# 8/8 [==============================] - 125s 16s/step - loss: 2.5614 - accuracy: 0.3984 - val_loss: 18.9508 - val_accuracy: 0.1842
# Epoch 7/30
# 8/8 [==============================] - 129s 16s/step - loss: 2.0143 - accuracy: 0.5365 - val_loss: 14.6067 - val_accuracy: 0.1316
# Epoch 8/30
# 8/8 [==============================] - 125s 16s/step - loss: 1.4896 - accuracy: 0.6458 - val_loss: 15.6002 - val_accuracy: 0.0789
# Epoch 9/30
# 8/8 [==============================] - 126s 16s/step - loss: 1.0499 - accuracy: 0.7526 - val_loss: 11.7189 - val_accuracy: 0.1579
# Epoch 10/30
# 8/8 [==============================] - 127s 16s/step - loss: 0.7169 - accuracy: 0.8724 - val_loss: 11.7655 - val_accuracy: 0.1316
# Epoch 11/30
# 8/8 [==============================] - 126s 16s/step - loss: 0.5017 - accuracy: 0.9036 - val_loss: 6.2606 - val_accuracy: 0.1842
# Epoch 12/30
# 8/8 [==============================] - 134s 17s/step - loss: 0.2717 - accuracy: 0.9740 - val_loss: 6.9161 - val_accuracy: 0.2105
# Epoch 13/30
# 8/8 [==============================] - 127s 16s/step - loss: 0.1774 - accuracy: 0.9818 - val_loss: 4.6888 - val_accuracy: 0.2895
# Epoch 14/30
# 8/8 [==============================] - 126s 16s/step - loss: 0.1055 - accuracy: 0.9948 - val_loss: 5.4843 - val_accuracy: 0.2368
# Epoch 15/30
# 8/8 [==============================] - 129s 16s/step - loss: 0.0622 - accuracy: 0.9974 - val_loss: 2.8152 - val_accuracy: 0.3158
# Epoch 16/30
# 8/8 [==============================] - 125s 16s/step - loss: 0.0357 - accuracy: 1.0000 - val_loss: 2.3455 - val_accuracy: 0.3947
# Epoch 17/30
# 8/8 [==============================] - 135s 17s/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 1.8865 - val_accuracy: 0.4474
# Epoch 18/30
# 8/8 [==============================] - 128s 16s/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.8538 - val_accuracy: 0.7632
# Epoch 19/30
# 8/8 [==============================] - 130s 16s/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.6482 - val_accuracy: 0.8158
# Epoch 20/30
# 8/8 [==============================] - 128s 16s/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.4503 - val_accuracy: 0.8947
# Epoch 21/30
# 8/8 [==============================] - 128s 16s/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.2756 - val_accuracy: 0.9211
# Epoch 22/30
# 8/8 [==============================] - 141s 16s/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.1967 - val_accuracy: 1.0000
# Epoch 23/30
# 8/8 [==============================] - 128s 16s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.1732 - val_accuracy: 1.0000
# Epoch 24/30
# 8/8 [==============================] - 126s 16s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.1606 - val_accuracy: 1.0000
# Epoch 25/30
# 8/8 [==============================] - 126s 16s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 1.0000
# Epoch 26/30
# 8/8 [==============================] - 138s 17s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.1314 - val_accuracy: 1.0000
# Epoch 27/30
# 8/8 [==============================] - 129s 16s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 1.0000
# Epoch 28/30
# 8/8 [==============================] - 128s 16s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 1.0000
# Epoch 29/30
# 8/8 [==============================] - 130s 16s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1022 - val_accuracy: 1.0000
# Epoch 30/30
# 8/8 [==============================] - 127s 16s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 1.0000

# %%
plt.figure(figsize=(16, 10));

plt.subplot(2, 2, 1);
plt.title('Обучающая выборка', fontweight='bold');
plt.plot(history.history['accuracy'], label='Точность на обучащей выборке');
plt.plot(history.history['loss'], label='Ошибка на обучащей выборке');
plt.xlabel('Эпоха обучения');
plt.legend()

plt.subplot(2, 2, 2);
plt.title('Проверочная выборка', fontweight='bold');
plt.plot(history.history['val_accuracy'], label='Точность на проверочной выборке');
plt.plot(history.history['val_loss'], label='Ошибка на проверочной выборке');
plt.xlabel('Эпоха обучения');
plt.legend();

plt.show();

# %%
val_acc = history.history['val_accuracy']

for i in range(30):
    print('Эпоха: {:2} точность: {:5.1%}'.format(i, val_acc[i]))
# Out:
# Эпоха:  0 точность:  7.9%
# Эпоха:  1 точность:  0.0%
# Эпоха:  2 точность:  0.0%
# Эпоха:  3 точность: 13.2%
# Эпоха:  4 точность: 10.5%
# Эпоха:  5 точность: 18.4%
# Эпоха:  6 точность: 13.2%
# Эпоха:  7 точность:  7.9%
# Эпоха:  8 точность: 15.8%
# Эпоха:  9 точность: 13.2%
# Эпоха: 10 точность: 18.4%
# Эпоха: 11 точность: 21.1%
# Эпоха: 12 точность: 28.9%
# Эпоха: 13 точность: 23.7%
# Эпоха: 14 точность: 31.6%
# Эпоха: 15 точность: 39.5%
# Эпоха: 16 точность: 44.7%
# Эпоха: 17 точность: 76.3%
# Эпоха: 18 точность: 81.6%
# Эпоха: 19 точность: 89.5%
# Эпоха: 20 точность: 92.1%
# Эпоха: 21 точность: 100.0%
# Эпоха: 22 точность: 100.0%
# Эпоха: 23 точность: 100.0%
# Эпоха: 24 точность: 100.0%
# Эпоха: 25 точность: 100.0%
# Эпоха: 26 точность: 100.0%
# Эпоха: 27 точность: 100.0%
# Эпоха: 28 точность: 100.0%
# Эпоха: 29 точность: 100.0%

# %%
model2 = Sequential();
model2.add(Conv2D(512, (3, 3), padding='same', activation='relu', input_shape=(100, 100, 3)));
model2.add(BatchNormalization());
model2.add(Conv2D(256, (3, 3), strides = (3,3), padding='same', activation='relu'));
model2.add(MaxPooling2D(pool_size=(3, 3)));
model2.add(BatchNormalization());
model2.add(Conv2D(128, (3, 3), strides = (3,3), padding='valid', activation='relu'));
model2.add(MaxPooling2D(pool_size=(3, 3)));
model2.add(Flatten());
model2.add(Dense(NUM_CLASSES, activation='softmax'));
print(model2.summary());
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 100, 100, 512)     14336
#
#  batch_normalization_2 (Batc  (None, 100, 100, 512)    2048
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 34, 34, 256)       1179904
#
#  max_pooling2d_2 (MaxPooling  (None, 11, 11, 256)      0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 11, 11, 256)      1024
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 128)         295040
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
# =================================================================
# Total params: 1,508,864
# Trainable params: 1,507,328
# Non-trainable params: 1,536
# _________________________________________________________________
# None

# %%
# Компиляция модели
model2.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# %%
history2 = model2.fit(x_train, y_train, validation_split=0.2, batch_size=50, epochs=30, verbose=1)
# Out:
# Epoch 1/30
# 7/7 [==============================] - 110s 16s/step - loss: 5.6219 - accuracy: 0.0163 - val_loss: 72.3077 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 7/7 [==============================] - 109s 15s/step - loss: 4.5415 - accuracy: 0.0521 - val_loss: 68.3205 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 7/7 [==============================] - 116s 17s/step - loss: 3.9563 - accuracy: 0.1010 - val_loss: 69.8514 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 7/7 [==============================] - 104s 15s/step - loss: 3.5290 - accuracy: 0.1759 - val_loss: 65.7695 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 7/7 [==============================] - 110s 16s/step - loss: 2.9869 - accuracy: 0.2834 - val_loss: 53.6906 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 7/7 [==============================] - 105s 15s/step - loss: 2.4414 - accuracy: 0.4169 - val_loss: 55.8417 - val_accuracy: 0.0000e+00
# Epoch 7/30
# 7/7 [==============================] - 107s 15s/step - loss: 1.9861 - accuracy: 0.4853 - val_loss: 46.8726 - val_accuracy: 0.0000e+00
# Epoch 8/30
# 7/7 [==============================] - 109s 15s/step - loss: 1.5599 - accuracy: 0.6091 - val_loss: 44.5309 - val_accuracy: 0.0000e+00
# Epoch 9/30
# 7/7 [==============================] - 104s 15s/step - loss: 1.1827 - accuracy: 0.7134 - val_loss: 41.5598 - val_accuracy: 0.0000e+00
# Epoch 10/30
# 7/7 [==============================] - 108s 15s/step - loss: 1.0377 - accuracy: 0.7329 - val_loss: 40.3624 - val_accuracy: 0.0000e+00
# Epoch 11/30
# 7/7 [==============================] - 109s 16s/step - loss: 0.6692 - accuracy: 0.8502 - val_loss: 44.8316 - val_accuracy: 0.0000e+00
# Epoch 12/30
# 7/7 [==============================] - 110s 16s/step - loss: 0.5188 - accuracy: 0.8990 - val_loss: 36.7659 - val_accuracy: 0.0000e+00
# Epoch 13/30
# 7/7 [==============================] - 107s 15s/step - loss: 0.4844 - accuracy: 0.8958 - val_loss: 37.4136 - val_accuracy: 0.0000e+00
# Epoch 14/30
# 7/7 [==============================] - 107s 15s/step - loss: 0.3224 - accuracy: 0.9381 - val_loss: 33.9547 - val_accuracy: 0.0000e+00
# Epoch 15/30
# 7/7 [==============================] - 108s 15s/step - loss: 0.2427 - accuracy: 0.9577 - val_loss: 30.5678 - val_accuracy: 0.0000e+00
# Epoch 16/30
# 7/7 [==============================] - 104s 15s/step - loss: 0.2015 - accuracy: 0.9674 - val_loss: 29.1308 - val_accuracy: 0.0000e+00
# Epoch 17/30
# 7/7 [==============================] - 108s 15s/step - loss: 0.1000 - accuracy: 0.9935 - val_loss: 26.3651 - val_accuracy: 0.0000e+00
# Epoch 18/30
# 7/7 [==============================] - 104s 15s/step - loss: 0.1439 - accuracy: 0.9805 - val_loss: 29.7734 - val_accuracy: 0.0000e+00
# Epoch 19/30
# 7/7 [==============================] - 108s 15s/step - loss: 0.3090 - accuracy: 0.9349 - val_loss: 28.5256 - val_accuracy: 0.0000e+00
# Epoch 20/30
# 7/7 [==============================] - 104s 15s/step - loss: 0.2271 - accuracy: 0.9316 - val_loss: 27.6521 - val_accuracy: 0.0000e+00
# Epoch 21/30
# 7/7 [==============================] - 108s 15s/step - loss: 0.1995 - accuracy: 0.9642 - val_loss: 27.8201 - val_accuracy: 0.0000e+00
# Epoch 22/30
# 7/7 [==============================] - 108s 15s/step - loss: 0.1231 - accuracy: 0.9772 - val_loss: 27.4086 - val_accuracy: 0.0000e+00
# Epoch 23/30
# 7/7 [==============================] - 108s 15s/step - loss: 0.1974 - accuracy: 0.9707 - val_loss: 26.4427 - val_accuracy: 0.0000e+00
# Epoch 24/30
# 7/7 [==============================] - 104s 15s/step - loss: 0.1545 - accuracy: 0.9772 - val_loss: 22.8006 - val_accuracy: 0.0260
# Epoch 25/30
# 7/7 [==============================] - 107s 15s/step - loss: 0.0947 - accuracy: 0.9837 - val_loss: 25.1749 - val_accuracy: 0.0260
# Epoch 26/30
# 7/7 [==============================] - 107s 15s/step - loss: 0.0652 - accuracy: 0.9935 - val_loss: 22.6068 - val_accuracy: 0.0260
# Epoch 27/30
# 7/7 [==============================] - 109s 15s/step - loss: 0.3106 - accuracy: 0.9349 - val_loss: 21.8924 - val_accuracy: 0.0130
# Epoch 28/30
# 7/7 [==============================] - 108s 15s/step - loss: 0.1430 - accuracy: 0.9772 - val_loss: 22.5645 - val_accuracy: 0.0260
# Epoch 29/30
# 7/7 [==============================] - 108s 15s/step - loss: 0.0897 - accuracy: 0.9870 - val_loss: 19.9277 - val_accuracy: 0.0260
# Epoch 30/30
# 7/7 [==============================] - 104s 15s/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 21.2837 - val_accuracy: 0.0130

# %%
plt.figure(figsize=(16, 10));

plt.subplot(2, 2, 1);
plt.title('Обучающая выборка', fontweight='bold');
plt.plot(history2.history['accuracy'], label='Точность на обучащей выборке');
plt.plot(history2.history['loss'], label='Ошибка на обучащей выборке');
plt.xlabel('Эпоха обучения');
plt.legend()

plt.subplot(2, 2, 2);
plt.title('Проверочная выборка', fontweight='bold');
plt.plot(history2.history['val_accuracy'], label='Точность на проверочной выборке');
plt.plot(history2.history['val_loss'], label='Ошибка на проверочной выборке');
plt.xlabel('Эпоха обучения');
plt.legend();

plt.show();
