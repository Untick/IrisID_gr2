# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/IrisID_gr2/blob/Andrey-Fedorenko-folder/Andrey%20Fedorenko/%D0%9F%D1%80%D0%BE%D0%B5%D0%BA%D1%82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gdown 
gdown.download_folder('https://drive.google.com/drive/folders/1mSg0kcNDoRV6w3td9VV7edT9oDA6n2sR?usp=sharing', None, quiet=True)
# Out:
# ['/content/Iris_ID/iris1_8.zip',
#  '/content/Iris_ID/iris9_16.zip',
#  '/content/Iris_ID/iris17_24.zip',
#  '/content/Iris_ID/iris25_32.zip',
#  '/content/Iris_ID/iris33_40.zip',
#  '/content/Iris_ID/iris41_48.zip',
#  '/content/Iris_ID/iris49_56.zip',
#  '/content/Iris_ID/iris57_64.zip']

# %%
import os
a = os.listdir('/content/Iris_ID')
for i in range(len(a)):
  print(a[i])
# Out:
# iris57_64.zip
# iris49_56.zip
# iris1_8.zip
# iris33_40.zip
# iris41_48.zip
# iris25_32.zip
# iris17_24.zip
# iris9_16.zip

# %%
for i in range(len(a)):
  # !unzip -qo "/content/Iris_ID/{a[i]}" -d /content/eyes

# %%
b = os.listdir('/content/eyes')
print(b)
# Out:
# ['036R_3.png', '008R_2.png', '063R_3.png', '018R_3.png', '050L_2.png', '041L_3.png', '032R_1.png', '043R_3.png', '049R_1.png', '011L_1.png', '016L_3.png', '016L_2.png', '027L_2.png', '009R_3.png', '032R_3.png', '003L_1.png', '042R_1.png', '040R_2.png', '030L_3.png', '018L_3.png', '048L_1.png', '061L_3.png', '006R_3.png', '011R_1.png', '039R_2.png', '028L_1.png', '035L_1.png', '015R_3.png', '058R_1.png', '046L_1.png', '018L_1.png', '045R_1.png', '016R_1.png', '013L_1.png', '040L_1.png', '039R_3.png', '002L_3.png', '048L_3.png', '032L_2.png', '040L_3.png', '055R_3.png', '046L_3.png', '004L_2.png', '037R_1.png', '025R_3.png', '009L_1.png', '061R_3.png', '009R_2.png', '042R_3.png', '056R_1.png', '058R_3.png', '017R_2.png', '059R_3.png', '007R_2.png', '053R_1.png', '061L_2.png', '048R_3.png', '033R_2.png', '015R_1.png', '055R_1.png', '046R_2.png', '045L_1.png', '010R_3.png', '015L_3.png', '002L_2.png', '047R_2.png', '029L_2.png', '034L_1.png', '048L_2.png', '012L_1.png', '008L_3.png', '06
# ...

# %%
from PIL import Image                     # Отрисовка изображений
import random                             # Генерация случайных чисел 
import matplotlib.pyplot as plt           # Отрисовка графиков

# %matplotlib inline

# %%
IMAGE_PATH = '/content/eyes/'

# %%
fig, axs = plt.subplots(1, 1 , figsize=(25, 5))
eyes_path = '/content/eyes/001L_3.png' 
axs.set_title('Глаз')
axs.imshow(Image.open(eyes_path))  
axs.axis('off')

# Отрисовка всего полотна
plt.show()

# %%
patient = list()
for i in range(1,10):
  patient.append('00'+str(i))
for i in range(10,65):
  patient.append('0'+str(i))
print(patient)




train_data = [] 
data_labels = []
k = 0
for i in patient: 
  for j in os.listdir('eyes/'): 
    if i in j:
      q = list()
      q.append(j)
      train_data.append('/content/eyes/'+ j)
# Out:
# ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064']

# %%
for i in range(1,65):
  for j in range(6):
    data_labels.append(i)

# %% [markdown]
# **Мы разметили данные**

# %%
print(train_data)

print(data_labels)
# Out:
# ['/content/eyes/001R_1.png', '/content/eyes/001L_2.png', '/content/eyes/001L_3.png', '/content/eyes/001R_2.png', '/content/eyes/001L_1.png', '/content/eyes/001R_3.png', '/content/eyes/002L_3.png', '/content/eyes/002L_2.png', '/content/eyes/002R_3.png', '/content/eyes/002R_2.png', '/content/eyes/002L_1.png', '/content/eyes/002R_1.png', '/content/eyes/003L_1.png', '/content/eyes/003L_3.png', '/content/eyes/003R_2.png', '/content/eyes/003R_3.png', '/content/eyes/003R_1.png', '/content/eyes/003L_2.png', '/content/eyes/004L_2.png', '/content/eyes/004R_1.png', '/content/eyes/004L_1.png', '/content/eyes/004R_3.png', '/content/eyes/004R_2.png', '/content/eyes/004L_3.png', '/content/eyes/005L_3.png', '/content/eyes/005L_2.png', '/content/eyes/005L_1.png', '/content/eyes/005R_3.png', '/content/eyes/005R_1.png', '/content/eyes/005R_2.png', '/content/eyes/006R_3.png', '/content/eyes/006L_2.png', '/content/eyes/006R_1.png', '/content/eyes/006L_3.png', '/content/eyes/006L_1.png', '/content/eyes/00
# ...
